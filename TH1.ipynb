# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# %matplotlib inline

# %%
# !git clone https://github.com/datnguyen305/SE365.git
# Out:
# Cloning into 'SE365'...
# remote: Enumerating objects: 266, done.
# remote: Counting objects: 100% (266/266), done.
# remote: Compressing objects: 100% (179/179), done.
# remote: Total 266 (delta 144), reused 198 (delta 76), pack-reused 0 (from 0)
# Receiving objects: 100% (266/266), 209.61 KiB | 1.73 MiB/s, done.
# Resolving deltas: 100% (144/144), done.

# %%
# !ls
# Out:
# SE365

# %%
cd SE365
# Out:
# /kaggle/working/SE365

# %%
pip install yacs
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python main.py --config configs/baseline_Adam.yaml
# Out:
# Cat: train=10000, dev=1250, test=1251
# ...
# Epoch [1/10]:  91%|█████████████▋ | 143/157 [00:32<00:03,  4.45it/s, loss=0.693]Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
#  -> Best model saved at epoch 1
# Epoch 1/10, Dev Accuracy: 0.5000, Dev F1: 0.0016
# ...
# Epoch [2/10]:  94%|██████████████ | 147/157 [00:32<00:02,  4.50it/s, loss=0.693]Corrupt JPEG data: 226 extraneous bytes before marker 0xd9
# Epoch 2/10, Dev Accuracy: 0.5004, Dev F1: 0.6668
# ...
# Epoch [3/10]:  54%|████████▌       | 84/157 [00:18<00:15,  4.62it/s, loss=0.694]Corrupt JPEG data: 128 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 399 extraneous bytes before marker 0xd9
# ...
# Epoch [3/10]:  97%|██████████████▌| 153/157 [00:33<00:00,  4.49it/s, loss=0.695]Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
# Epoch 3/10, Dev Accuracy: 0.5000, Dev F1: 0.0000
# ...
# Epoch [4/10]:  91%|█████████████▋ | 143/157 [00:31<00:03,  4.39it/s, loss=0.693]Corrupt JPEG data: 226 extraneous bytes before marker 0xd9
# ...

# %%
from IPython.display import Image, display

# Hiển thị Confusion Matrix
print("--- Confusion Matrix ---")
display(Image(filename='checkpoints/confusion_matrix_baseline_Adam.png'))

# Hiển thị Learning Curves
print("\n--- Learning Curves ---")
display(Image(filename='checkpoints/learning_curves_baseline_Adam.png'))
# Out:
# --- Confusion Matrix ---
# --- Learning Curves ---

# %%
# !python main.py --config configs/baseline_SGD_Momentum.yaml
# Out:
# --- Dữ liệu đã tồn tại trong 'data/preprocessed'. Bỏ qua bước tiền xử lý. ---
# ...
# Epoch [1/10]:  91%|█████████████▋ | 143/157 [00:31<00:03,  4.52it/s, loss=0.694]Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
#  -> Best model saved at epoch 1
# Epoch 1/10, Dev Accuracy: 0.5276, Dev F1: 0.4145
# ...
# Epoch [2/10]:  94%|██████████████▉ | 147/157 [00:32<00:02,  4.57it/s, loss=0.69]Corrupt JPEG data: 226 extraneous bytes before marker 0xd9
#  -> Best model saved at epoch 2
# Epoch 2/10, Dev Accuracy: 0.5792, Dev F1: 0.6357
# ...
# Epoch [3/10]:  54%|████████▌       | 84/157 [00:18<00:16,  4.55it/s, loss=0.688]Corrupt JPEG data: 128 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 399 extraneous bytes before marker 0xd9
# ...
# Epoch [3/10]:  97%|██████████████▌| 153/157 [00:33<00:00,  4.53it/s, loss=0.685]Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
#  -> Best model saved at epoch 3
# Epoch 3/10, Dev Accuracy: 0.5748, Dev F1: 0.6310
# ...

# %%
from IPython.display import Image, display

# Hiển thị Confusion Matrix
print("--- Confusion Matrix ---")
display(Image(filename='checkpoints/confusion_matrix_baseline_SGD_Momentum.png'))

# Hiển thị Learning Curves
print("\n--- Learning Curves ---")
display(Image(filename='checkpoints/learning_curves_baseline_SGD_Momentum.png'))
# Out:
# --- Confusion Matrix ---
# --- Learning Curves ---

# %%
# !python main.py --config configs/exp_0.yaml
# Out:
# --- Dữ liệu đã tồn tại trong 'data/preprocessed'. Bỏ qua bước tiền xử lý. ---
# ...
# Epoch [1/10]:  91%|█████████████▋ | 143/157 [00:31<00:03,  4.52it/s, loss=0.641]Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
#  -> Best model saved at epoch 1
# Epoch 1/10, Dev Accuracy: 0.5804, Dev F1: 0.6797
# ...
# Epoch [2/10]:  94%|██████████████ | 147/157 [00:32<00:02,  4.61it/s, loss=0.652]Corrupt JPEG data: 226 extraneous bytes before marker 0xd9
# Epoch 2/10, Dev Accuracy: 0.5820, Dev F1: 0.6425
# ...
# Epoch [3/10]:  54%|████████▌       | 84/157 [00:18<00:15,  4.75it/s, loss=0.646]Corrupt JPEG data: 128 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 399 extraneous bytes before marker 0xd9
# ...
# Epoch [3/10]:  97%|██████████████▌| 153/157 [00:33<00:00,  4.54it/s, loss=0.659]Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
#  -> Best model saved at epoch 3
# Epoch 3/10, Dev Accuracy: 0.5736, Dev F1: 0.4723
# ...

# %%
from IPython.display import Image, display

# Hiển thị Confusion Matrix
print("--- Confusion Matrix ---")
display(Image(filename='checkpoints/confusion_matrix_exp_0.png'))

# Hiển thị Learning Curves
print("\n--- Learning Curves ---")
display(Image(filename='checkpoints/learning_curves_exp_0.png'))
# Out:
# --- Confusion Matrix ---
# --- Learning Curves ---

# %%
# !python main.py --config configs/exp_1.yaml
# Out:
# --- Dữ liệu đã tồn tại trong 'data/preprocessed'. Bỏ qua bước tiền xử lý. ---
# ...
# Epoch [1/10]:  91%|█████████████▋ | 143/157 [00:31<00:03,  4.59it/s, loss=0.646]Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
#  -> Best model saved at epoch 1
# Epoch 1/10, Dev Accuracy: 0.5872, Dev F1: 0.6619
# ...
# Epoch [2/10]:  94%|██████████████ | 147/157 [00:32<00:02,  4.42it/s, loss=0.661]Corrupt JPEG data: 226 extraneous bytes before marker 0xd9
#  -> Best model saved at epoch 2
# Epoch 2/10, Dev Accuracy: 0.6104, Dev F1: 0.6268
# ...
# Epoch [3/10]:  54%|████████▌       | 84/157 [00:18<00:16,  4.48it/s, loss=0.656]Corrupt JPEG data: 128 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 399 extraneous bytes before marker 0xd9
# ...
# Epoch [3/10]:  97%|██████████████▌| 153/157 [00:34<00:00,  4.49it/s, loss=0.647]Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
# Epoch 3/10, Dev Accuracy: 0.5948, Dev F1: 0.4808
# ...

# %%
from IPython.display import Image, display

# Hiển thị Confusion Matrix
print("--- Confusion Matrix ---")
display(Image(filename='checkpoints/confusion_matrix_exp_1.png'))

# Hiển thị Learning Curves
print("\n--- Learning Curves ---")
display(Image(filename='checkpoints/learning_curves_exp_1.png'))
# Out:
# --- Confusion Matrix ---
# --- Learning Curves ---

# %%
# !python main.py --config configs/exp_2.yaml
# Out:
# --- Dữ liệu đã tồn tại trong 'data/preprocessed'. Bỏ qua bước tiền xử lý. ---
# ...
# Epoch [1/10]:  91%|█████████████▋ | 143/157 [00:31<00:03,  4.63it/s, loss=0.689]Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
#  -> Best model saved at epoch 1
# Epoch 1/10, Dev Accuracy: 0.5292, Dev F1: 0.6715
# ...
# Epoch [2/10]:  94%|██████████████ | 147/157 [00:32<00:02,  4.55it/s, loss=0.693]Corrupt JPEG data: 226 extraneous bytes before marker 0xd9
# Epoch 2/10, Dev Accuracy: 0.5020, Dev F1: 0.6672
# ...
# Epoch [3/10]:  54%|████████▌       | 84/157 [00:18<00:15,  4.61it/s, loss=0.695]Corrupt JPEG data: 128 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 399 extraneous bytes before marker 0xd9
# ...
# Epoch [3/10]:  97%|██████████████▌| 153/157 [00:33<00:00,  4.54it/s, loss=0.695]Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
# Epoch 3/10, Dev Accuracy: 0.5000, Dev F1: 0.0000
# ...

# %%
from IPython.display import Image, display

# Hiển thị Confusion Matrix
print("--- Confusion Matrix ---")
display(Image(filename='checkpoints/confusion_matrix_exp_2.png'))

# Hiển thị Learning Curves
print("\n--- Learning Curves ---")
display(Image(filename='checkpoints/learning_curves_exp_2.png'))
# Out:
# --- Confusion Matrix ---
# --- Learning Curves ---

# %%
# !python main.py --config configs/exp_3.yaml
# Out:
# --- Dữ liệu đã tồn tại trong 'data/preprocessed'. Bỏ qua bước tiền xử lý. ---
# ...
# Epoch [1/10]:  91%|█████████████▋ | 143/157 [00:49<00:04,  2.92it/s, loss=0.694]Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
#  -> Best model saved at epoch 1
# Epoch 1/10, Dev Accuracy: 0.5000, Dev F1: 0.0000
# ...
# Epoch [2/10]:  94%|██████████████ | 147/157 [00:50<00:03,  2.91it/s, loss=0.693]Corrupt JPEG data: 226 extraneous bytes before marker 0xd9
#  -> Best model saved at epoch 2
# Epoch 2/10, Dev Accuracy: 0.5008, Dev F1: 0.6668
# ...
# Epoch [3/10]:  54%|████████▌       | 84/157 [00:28<00:24,  2.98it/s, loss=0.694]Corrupt JPEG data: 128 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 399 extraneous bytes before marker 0xd9
# ...
# Epoch [3/10]:  97%|██████████████▌| 153/157 [00:52<00:01,  3.03it/s, loss=0.695]Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
#  -> Best model saved at epoch 3
# Epoch 3/10, Dev Accuracy: 0.5000, Dev F1: 0.0000
# ...

# %%
from IPython.display import Image, display

# Hiển thị Confusion Matrix
print("--- Confusion Matrix ---")
display(Image(filename='checkpoints/confusion_matrix_exp_3.png'))

# Hiển thị Learning Curves
print("\n--- Learning Curves ---")
display(Image(filename='checkpoints/learning_curves_exp_3.png'))
# Out:
# --- Confusion Matrix ---
# --- Learning Curves ---

# %%
# !python main.py --config configs/exp_4.yaml
# Out:
# --- Dữ liệu đã tồn tại trong 'data/preprocessed'. Bỏ qua bước tiền xử lý. ---
# ...
# Epoch [1/10]:  91%|█████████████▋ | 143/157 [00:49<00:04,  2.92it/s, loss=0.694]Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
#  -> Best model saved at epoch 1
# Epoch 1/10, Dev Accuracy: 0.5000, Dev F1: 0.0000
# ...
# Epoch [2/10]:  94%|██████████████ | 147/157 [00:50<00:03,  2.94it/s, loss=0.693]Corrupt JPEG data: 226 extraneous bytes before marker 0xd9
#  -> Best model saved at epoch 2
# Epoch 2/10, Dev Accuracy: 0.5008, Dev F1: 0.6668
# ...
# Epoch [3/10]:  54%|████████▌       | 84/157 [00:28<00:24,  2.98it/s, loss=0.694]Corrupt JPEG data: 128 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 399 extraneous bytes before marker 0xd9
# ...
# Epoch [3/10]:  97%|██████████████▌| 153/157 [00:52<00:01,  2.96it/s, loss=0.695]Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
#  -> Best model saved at epoch 3
# Epoch 3/10, Dev Accuracy: 0.5000, Dev F1: 0.0000
# ...

# %%
from IPython.display import Image, display

# Hiển thị Confusion Matrix
print("--- Confusion Matrix ---")
display(Image(filename='checkpoints/confusion_matrix_exp_4.png'))

# Hiển thị Learning Curves
print("\n--- Learning Curves ---")
display(Image(filename='checkpoints/learning_curves_exp_4.png'))
# Out:
# --- Confusion Matrix ---
# --- Learning Curves ---
