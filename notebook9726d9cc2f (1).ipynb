# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# %matplotlib inline

# %%
# !git clone https://github.com/datnguyen305/SE365.git
# Out:
# Cloning into 'SE365'...
# remote: Enumerating objects: 228, done.
# remote: Counting objects: 100% (228/228), done.
# remote: Compressing objects: 100% (150/150), done.
# remote: Total 228 (delta 119), reused 176 (delta 67), pack-reused 0 (from 0)
# Receiving objects: 100% (228/228), 203.83 KiB | 20.38 MiB/s, done.
# Resolving deltas: 100% (119/119), done.

# %%
# !ls
# Out:
# SE365

# %%
cd SE365
# Out:
# /kaggle/working/SE365

# %%
pip install yacs
# Out:
# Collecting yacs
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from yacs) (6.0.3)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Installing collected packages: yacs
# Successfully installed yacs-0.1.8
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python main.py --config configs/baseline_Adam.yaml

# %%
# !python main.py --config configs/baseline_SGD_Momentum.yaml
# Out:
# Cat: train=10000, dev=1250, test=1251
# Epoch [1/1]:   1%|▏                 | 2/157 [00:00<01:00,  2.56it/s, loss=0.694]Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
# Epoch [1/1]:  18%|███▏             | 29/157 [00:06<00:28,  4.50it/s, loss=0.693]Corrupt JPEG data: 1403 extraneous bytes before marker 0xd9
# Epoch [1/1]:  27%|████▋            | 43/157 [00:09<00:25,  4.54it/s, loss=0.693]Corrupt JPEG data: 65 extraneous bytes before marker 0xd9
# Epoch [1/1]:  31%|█████▎           | 49/157 [00:11<00:23,  4.56it/s, loss=0.686]Corrupt JPEG data: 214 extraneous bytes before marker 0xd9
# Epoch [1/1]:  46%|███████▊         | 72/157 [00:16<00:19,  4.42it/s, loss=0.676]Corrupt JPEG data: 128 extraneous bytes before marker 0xd9
# Epoch [1/1]:  54%|█████████        | 84/157 [00:18<00:16,  4.56it/s, loss=0.688]Corrupt JPEG data: 226 extraneous bytes before marker 0xd9
# Epoch [1/1]:  67%|██████████▋     | 105/157 [00:23<00:11,  4.44it/s, loss=0.695]Corrupt JPEG data: 399 extraneous bytes before marker 0xd9
# Epoch [1/1]:  80%|████████████▋   | 125/157 [00:27<00:07,  4.53it/s, loss=0.667]Corrupt JPEG data: 2230 extraneous bytes before marker 0xd9
# Epoch [1/1]:  83%|█████████████▎  | 131/157 [00:29<00:05,  4.60it/s, loss=0.692]Warning: unknown JFIF revision number 0.00
#  -> Best model saved at epoch 1
# Epoch 1/1, Dev Accuracy: 0.5956, Dev F1: 0.5711
# Testing:  10%|███▌                               | 2/20 [00:00<00:04,  4.48it/s]Corrupt JPEG data: 239 extraneous bytes before marker 0xd9
# Testing:  20%|███████                            | 4/20 [00:00<00:03,  4.68it/s]Corrupt JPEG data: 1153 extraneous bytes before marker 0xd9
# Testing:  35%|████████████▎                      | 7/20 [00:01<00:02,  4.69it/s]Corrupt JPEG data: 99 extraneous bytes before marker 0xd9
# Testing:  60%|████████████████████▍             | 12/20 [00:02<00:01,  4.70it/s]Corrupt JPEG data: 254 extraneous bytes before marker 0xd9
# Testing: 100%|██████████████████████████████████| 20/20 [00:04<00:00,  4.73it/s]
#  -> Saved predictions and targets to checkpoints
# Test Loss: 0.6740 | Test Acc: 0.5983 | Test F1: 0.5832
#  -> Biểu đồ đã được lưu tại: checkpoints/confusion_matrix_baseline_SGD_Momentum.png
# Figure(1000x800)
#  -> Learning curves saved at: checkpoints/learning_curves_baseline_SGD_Momentum.png
# Figure(1500x500)
# Final Test Results:
#  - accuracy: 0.5983
#  - precision: 0.6060
#  - recall: 0.5620
#  - test_f1: 0.5832

# %%
# !python main.py --config configs/exp_0.yaml

# %%
# !python main.py --config configs/exp_1.yaml
# Out:
# --- Dữ liệu đã tồn tại trong 'data/preprocessed'. Bỏ qua bước tiền xử lý. ---
# Epoch [1/10]:   1%|▎                   | 2/157 [00:01<01:32,  1.67it/s, loss=40]Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
# Epoch [1/10]:   4%|▋                 | 6/157 [00:02<00:59,  2.52it/s, loss=20.9]

# %%
# !python main.py --config configs/exp_2.yaml

# %%
# !python main.py --config configs/exp_3.yaml

# %%
# !python main.py --config configs/exp_4.yaml

# %%
# !ls

# %%
cd checkpoints
